# %%
import requests
from bs4 import BeautifulSoup     #importing all requied libraries
url="https://en.wikipedia.org/wiki/Google"   #storing url into url variable
code=requests.get(url)         #making a get request
text=code.text
soup=BeautifulSoup(text,"html.parser")
file1 = open("/content/drive/My Drive/Colab Notebooks/webscrap.txt","w")
for l in soup.find_all('p'):                  #printing all urls without anchor tag
    file1.writelines(str(l.get_text(strip=True)))

# %%
#Tokenization
import nltk

nltk.download('punkt')
file2 =open("/content/drive/My Drive/Colab Notebooks/webscrap.txt","r")
w=""
w=file2.readline()
word_token=nltk.word_tokenize(w)
for r in word_token:
   print(r)
# Out:
# Streaming output truncated to the last 5000 lines.
# for
# security
# issues
# of
# their
# websites
# ,
# as
# well
# as
# optimize
# their
# website
# 's
# visibility.Google
# offersGmailforemail
# ,
# [
# 122
# ]
# Google
# Calendarfor
# time-management
# and
# scheduling
# ,
# [
# 123
# ]
# Google
# Mapsfor
# mapping
# ,
# navigation
# andsatellite
# imagery
# ,
# [
# 124
# ]
# Google
# Driveforcloud
# storageof
# files
# ,
# [
# 125
# ]
# Google
# Docs
# ,
# SheetsandSlidesfor
# productivity
# ,
# [
# 125
# ]
# Google
# Photosfor
# photo
# storage
# and
# sharing
# ,
# [
# 126
# ]
# Google
# Keepfornote-taking
# ,
# [
# 127
# ]
# Google
# Translatefor
# language
# translation
# ,
# [
# 128
# ]
# YouTubefor
# video
# viewing
# and
# sharing
# ,
# [
# 129
# ]
# Google
# My
# Businessfor
# managing
# public
# business
# information
# ,
# [
# 130
# ]
# andDuofor
# social
# interaction
# .
# [
# 131
# ]
# In
# March
# 2019
# ,
# Google
# unveiled
# acloud
# gamingservice
# ...

# %%
#POS
nltk.download('averaged_perceptron_tagger')
tagged=nltk.pos_tag(word_token)
print(tagged)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ...

# %%
#Stemming
from nltk.stem import PorterStemmer
pStemmer=PorterStemmer()
for r in word_token:
   print(pStemmer.stem(r))
# Out:
# Streaming output truncated to the last 5000 lines.
# for
# secur
# issu
# of
# their
# websit
# ,
# as
# well
# as
# optim
# their
# websit
# 's
# visibility.googl
# offersgmailforemail
# ,
# [
# 122
# ]
# googl
# calendarfor
# time-manag
# and
# schedul
# ,
# [
# 123
# ]
# googl
# mapsfor
# map
# ,
# navig
# andsatellit
# imageri
# ,
# [
# 124
# ]
# googl
# driveforcloud
# storageof
# file
# ,
# [
# 125
# ]
# googl
# doc
# ,
# sheetsandslidesfor
# product
# ,
# [
# 125
# ]
# googl
# photosfor
# photo
# storag
# and
# share
# ,
# [
# 126
# ]
# googl
# keepfornote-tak
# ,
# [
# 127
# ]
# googl
# translatefor
# languag
# translat
# ,
# [
# 128
# ]
# youtubefor
# video
# view
# and
# share
# ,
# [
# 129
# ]
# googl
# My
# businessfor
# manag
# public
# busi
# inform
# ,
# [
# 130
# ]
# andduofor
# social
# interact
# .
# [
# 131
# ]
# In
# march
# 2019
# ,
# googl
# unveil
# acloud
# gamingservic
# namedstadia
# .
# [
# 103
# ]
# googl
# develop
# theandroidmobil
# oper
# system
# ,
# ...

# %%
#Lemmatization
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lem= WordNetLemmatizer()

for r in word_token:
   print(lem.lemmatize(r))
# Out:
# Streaming output truncated to the last 5000 lines.
# for
# security
# issue
# of
# their
# website
# ,
# a
# well
# a
# optimize
# their
# website
# 's
# visibility.Google
# offersGmailforemail
# ,
# [
# 122
# ]
# Google
# Calendarfor
# time-management
# and
# scheduling
# ,
# [
# 123
# ]
# Google
# Mapsfor
# mapping
# ,
# navigation
# andsatellite
# imagery
# ,
# [
# 124
# ]
# Google
# Driveforcloud
# storageof
# file
# ,
# [
# 125
# ]
# Google
# Docs
# ,
# SheetsandSlidesfor
# productivity
# ,
# [
# 125
# ]
# Google
# Photosfor
# photo
# storage
# and
# sharing
# ,
# [
# 126
# ]
# Google
# Keepfornote-taking
# ,
# [
# 127
# ]
# Google
# Translatefor
# language
# translation
# ,
# [
# 128
# ]
# YouTubefor
# video
# viewing
# and
# sharing
# ,
# [
# 129
# ]
# Google
# My
# Businessfor
# managing
# public
# business
# information
# ,
# [
# 130
# ]
# andDuofor
# social
# interaction
# .
# [
# 131
# ]
# In
# March
# 2019
# ,
# Google
# unveiled
# acloud
# gamingservice
# namedStadia
# ...

# %%
#Trigram
from nltk.util import ngrams
trigrams=ngrams(word_token,3)
for t in trigrams:
  print(t)
# Out:
# Streaming output truncated to the last 5000 lines.
# (',', 'and', 'for')
# ('and', 'for', 'security')
# ('for', 'security', 'issues')
# ('security', 'issues', 'of')
# ('issues', 'of', 'their')
# ('of', 'their', 'websites')
# ('their', 'websites', ',')
# ('websites', ',', 'as')
# (',', 'as', 'well')
# ('as', 'well', 'as')
# ('well', 'as', 'optimize')
# ('as', 'optimize', 'their')
# ('optimize', 'their', 'website')
# ('their', 'website', "'s")
# ('website', "'s", 'visibility.Google')
# ("'s", 'visibility.Google', 'offersGmailforemail')
# ('visibility.Google', 'offersGmailforemail', ',')
# ('offersGmailforemail', ',', '[')
# (',', '[', '122')
# ('[', '122', ']')
# ('122', ']', 'Google')
# (']', 'Google', 'Calendarfor')
# ('Google', 'Calendarfor', 'time-management')
# ('Calendarfor', 'time-management', 'and')
# ('time-management', 'and', 'scheduling')
# ('and', 'scheduling', ',')
# ('scheduling', ',', '[')
# (',', '[', '123')
# ('[', '123', ']')
# ('123', ']', 'Google')
# ...

# %%
#NAMED ENTITY RECOGNITION
from nltk import wordpunct_tokenize, pos_tag, ne_chunk
nltk.download('maxent_ne_chunker')
nltk.download('words')
print(ne_chunk(pos_tag(wordpunct_tokenize(w))))
# Out:
# Streaming output truncated to the last 5000 lines.
#   clicked/VBN
#   .[/JJ
#   120/CD
#   ]/JJ
#   One/CD
#   of/IN
#   the/DT
#   criticisms/NNS
#   of/IN
#   this/DT
#   program/NN
#   is/VBZ
#   the/DT
#   possibility/NN
#   ofclick/NN
#   fraud/NN
#   ,/,
#   which/WDT
#   occurs/VBZ
#   when/WRB
#   a/DT
#   person/NN
#   or/CC
#   automated/VBN
#   script/NN
#   clicks/NNS
#   on/IN
#   advertisements/NNS
#   without/IN
#   being/VBG
#   interested/JJ
#   in/IN
#   the/DT
#   product/NN
#   ,/,
#   causing/VBG
#   the/DT
#   advertiser/NN
#   to/TO
#   pay/VB
#   money/NN
#   to/TO
#   (PERSON Google/NNP)
#   unduly/RB
#   ./.
#   Industry/NN
#   reports/NNS
#   in/IN
#   2006/CD
#   claimed/VBD
#   that/IN
#   approximately/RB
#   14/CD
#   to/TO
#   20/CD
#   percent/NN
#   of/IN
#   clicks/NNS
#   were/VBD
#   fraudulent/JJ
#   or/CC
#   invalid/JJ
#   .[/NN
#   121/CD
#   ]/NN
#   (PERSON Google/NNP Search/NNP Console/NNP)
#   (/(
#   rebranded/VBN
#   from/IN
# ...
